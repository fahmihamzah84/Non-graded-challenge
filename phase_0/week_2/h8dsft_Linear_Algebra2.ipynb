# %%
from IPython import display
display.Image("./ngc4_1.png")

# %%
display.Image("./ngc4_2.png")

# %%
display.Image("./ngc4_3.png")

# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
M1 = np.array([[23,50],
            [7,12]
])
M2 = np.array([[57,67],
            [99,43]
])
M3 = np.array([[75,21],
            [57,12]
])
M4 = np.array([[87,26],
            [18,84]
])

# %%
tensor = np.array(([M1, M2, M3, M4]))

# %%
tensor
# Out:
# array([[[23, 50],
#         [ 7, 12]],
#
#        [[57, 67],
#         [99, 43]],
#
#        [[75, 21],
#         [57, 12]],
#
#        [[87, 26],
#         [18, 84]]])

# %% [markdown]
# Soal 2

# %%
A = np.array([
    [23,50,19],
    [7,12,109],
    [57,67,98]
])

# %%
B = np.array([
    [17,22,19]
])

# %%
print(A)
print(B)
# Out:
# [[ 23  50  19]
#  [  7  12 109]
#  [ 57  67  98]]
# [[17 22 19]]

# %%
print('Hasil dari perkalian dari matrix A dan B adalah =\n' +str(A * B))
# Out:
# Hasil dari perkalian dari matrik A dan B adalah =
# [[ 391 1100  361]
#  [ 119  264 2071]
#  [ 969 1474 1862]]

# %% [markdown]
# Soal 3

# %%
print('Hasil transpose dari matrix A adalah =\n')
A.T
# Out:
# Hasil transpose dari matrix A adalah =
# array([[ 23,   7,  57],
#        [ 50,  12,  67],
#        [ 19, 109,  98]])

# %%
print('Determinan dari matrix A adalah = ' + str(np.linalg.det(A)))
# Out:
# Determinan dari matrix A adalah = 131344.0000000002

# %%
print('Inverse dari matrix A adalah = \n' +str(np.linalg.inv(A)))
# Out:
# Inverse dari matrix A adalah =
# [[-0.0466485  -0.02761451  0.03975819]
#  [ 0.04208034  0.00891552 -0.01807467]
#  [-0.00163692  0.0099662  -0.00056341]]
